# %% [markdown]
# <h1 align="center">بالین!</h1>
# <h2 align="right">میتونید از لینک زیر به آن دسترسی پیدا کنید </h2>
#
#
# [سوال بالین! در کوئرا](https://quera.org/problemset/175884)

# %% [markdown]
# <h1 align="center">جواب سوال</h1>

# %%
def calculate_floor(string):
    out = 0
    for s in string:
        if s=='U':
            out +=1
        else:
            out -=1
    print(out)

# input: UUDU 
# correct result: 2
calculate_floor("UUDU")
# Out:
# 2
