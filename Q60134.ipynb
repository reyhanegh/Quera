# %% [markdown]
# <h1 align="center">شطرنج میوه‌ای</h1>
# <h2 align="right">میتونید از لینک زیر به آن دسترسی پیدا کنید </h2>
#
#
# [سوال شطرنج میوه‌ای در کوئرا](https://quera.org/problemset/60134)

# %% [markdown]
# <h1 align="center">جواب سوال</h1>

# %%
def fruits(tuple_of_fruits):
    output = {}
    for fruit in tuple_of_fruits:
        is_sphere = fruit['shape']== 'sphere'
        mass_ok =  300 <= fruit['mass'] <= 600
        volumn_ok = 100 <= fruit['volume'] <= 500

        if is_sphere and mass_ok and volumn_ok:
            name = fruit['name']

            if name in output:
                output[name] +=1
            else:
                output[name] = 1
    return output
# Out:
# 2
